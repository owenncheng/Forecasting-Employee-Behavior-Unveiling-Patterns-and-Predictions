# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('A2_change_job_labeled.csv')

# %%
df.head()
# Out:
#      cid  city.100  city.10  city.105  city.103  city.104  city.102  city.101  \
# 0   7124         0        0         0         0         0         0         0
# 1     51         0        0         1         0         0         0         0
# 2  13137         0        0         0         0         0         0         0
# 3   2769         0        0         0         0         0         0         0
# 4   8374         0        0         0         0         0         0         0
#
#    city.2119  city.114  ...  education_level  academic_discipline  experience  \
# 0          0         0  ...    Undergraduate                 STEM          15
# 1          0         0  ...    Undergraduate                 STEM           4
# 2          0         0  ...      High School                 STEM           8
# 3          0         0  ...    Undergraduate                 STEM           2
# 4          0         0  ...              PhD                 STEM           7
#
# ...

# %%
df['target'] = np.where(df['target'] == "yes", 1, 0)

# %%
df.head()
# Out:
#      cid  city.100  city.10  city.105  city.103  city.104  city.102  city.101  \
# 0   7124         0        0         0         0         0         0         0
# 1     51         0        0         1         0         0         0         0
# 2  13137         0        0         0         0         0         0         0
# 3   2769         0        0         0         0         0         0         0
# 4   8374         0        0         0         0         0         0         0
#
#    city.2119  city.114  ...  education_level  academic_discipline  experience  \
# 0          0         0  ...    Undergraduate                 STEM          15
# 1          0         0  ...    Undergraduate                 STEM           4
# 2          0         0  ...      High School                 STEM           8
# 3          0         0  ...    Undergraduate                 STEM           2
# 4          0         0  ...              PhD                 STEM           7
#
# ...

# %%
df['education_level'] = np.where(df['education_level'] == "Undergraduate", 0, df['education_level'])
df['education_level'] = np.where(df['education_level'] == "Masters", 1, df['education_level'])
df['education_level'] = np.where(df['education_level'] == "High School", 2, df['education_level'])
df['education_level'] = np.where(df['education_level'] == "PhD", 3, df['education_level'])
df['education_level'] = np.where(df['education_level'] == "Primary School", 4, df['education_level'])
df
# Out:
#          cid  city.100  city.10  city.105  city.103  city.104  city.102  \
# 0       7124         0        0         0         0         0         0
# 1         51         0        0         1         0         0         0
# 2      13137         0        0         0         0         0         0
# 3       2769         0        0         0         0         0         0
# 4       8374         0        0         0         0         0         0
# ...      ...       ...      ...       ...       ...       ...       ...
# 11489  14834         0        0         0         0         1         0
# 11490  14996         0        0         0         0         1         0
# 11491   5960         0        0         0         0         1         0
# 11492   5867         0        0         0         0         0         0
# 11493   8376         0        0         0         0         1         0
#
#        city.101  city.2119  city.114  ...  education_level  \
# ...

# %%
df['academic_discipline'] = np.where(df['academic_discipline'] == "STEM", 0, df['academic_discipline'])
df['academic_discipline'] = np.where(df['academic_discipline'] == "Humanities", 1, df['academic_discipline'])
df['academic_discipline'] = np.where(df['academic_discipline'] == "Other", 2, df['academic_discipline'])
df['academic_discipline'] = np.where(df['academic_discipline'] == "Business degree", 3, df['academic_discipline'])
df['academic_discipline'] = np.where(df['academic_discipline'] == "Arts", 4, df['academic_discipline'])
df['academic_discipline'] = np.where(df['academic_discipline'] == "No major", 5, df['academic_discipline'])
df
# Out:
#          cid  city.100  city.10  city.105  city.103  city.104  city.102  \
# 0       7124         0        0         0         0         0         0
# 1         51         0        0         1         0         0         0
# 2      13137         0        0         0         0         0         0
# 3       2769         0        0         0         0         0         0
# 4       8374         0        0         0         0         0         0
# ...      ...       ...      ...       ...       ...       ...       ...
# 11489  14834         0        0         0         0         1         0
# 11490  14996         0        0         0         0         1         0
# 11491   5960         0        0         0         0         1         0
# 11492   5867         0        0         0         0         0         0
# 11493   8376         0        0         0         0         1         0
#
#        city.101  city.2119  city.114  ...  education_level  \
# ...

# %%
df['experience']

# %%
df.academic_discipline.value_counts()
# Out:
# STEM               10085
# Humanities           501
# Other                288
# Business degree      227
# Arts                 199
# No major             194
# Name: academic_discipline, dtype: int64

# %%
df['company_type'] = np.where(df['company_type'] == "Pvt Ltd", 0, df['company_type'])
df['company_type'] = np.where(df['company_type'] == "Public sector", 1, df['company_type'])
df['company_type'] = np.where(df['company_type'] == "Early stage startup", 2, df['company_type'])
df['company_type'] = np.where(df['company_type'] == "Funded startup", 3, df['company_type'])
df['company_type'] = np.where(df['company_type'] == "NGO", 4, df['company_type'])
df['company_type'] = np.where(df['company_type'] == "Other", 5, df['company_type'])
df
# Out:
#          cid  city.100  city.10  city.105  city.103  city.104  city.102  \
# 0       7124         0        0         0         0         0         0
# 1         51         0        0         1         0         0         0
# 2      13137         0        0         0         0         0         0
# 3       2769         0        0         0         0         0         0
# 4       8374         0        0         0         0         0         0
# ...      ...       ...      ...       ...       ...       ...       ...
# 11489  14834         0        0         0         0         1         0
# 11490  14996         0        0         0         0         1         0
# 11491   5960         0        0         0         0         1         0
# 11492   5867         0        0         0         0         0         0
# 11493   8376         0        0         0         0         1         0
#
#        city.101  city.2119  city.114  ...  education_level  \
# ...

# %%
df.company_type.value_counts()
# Out:
# Pvt Ltd                7584
# Public sector          1208
# Early stage startup     954
# Funded startup          896
# NGO                     564
# Other                   288
# Name: company_type, dtype: int64

# %%
df['last_new_job'] = np.where(df['last_new_job'] == "never", 0, df['last_new_job'])
df['last_new_job'] = np.where(df['last_new_job'] == ">4", 5, df['last_new_job'])
df
# Out:
#          cid  city.100  city.10  city.105  city.103  city.104  city.102  \
# 0       7124         0        0         0         0         0         0
# 1         51         0        0         1         0         0         0
# 2      13137         0        0         0         0         0         0
# 3       2769         0        0         0         0         0         0
# 4       8374         0        0         0         0         0         0
# ...      ...       ...      ...       ...       ...       ...       ...
# 11489  14834         0        0         0         0         1         0
# 11490  14996         0        0         0         0         1         0
# 11491   5960         0        0         0         0         1         0
# 11492   5867         0        0         0         0         0         0
# 11493   8376         0        0         0         0         1         0
#
#        city.101  city.2119  city.114  ...  education_level  \
# ...

# %%
df.company_size.value_counts()
# Out:
# 50-99        2282
# 10000+       1821
# 100-500      1768
# <10          1435
# 1000-4999    1189
# Oct-49       1050
# 5000-9999    1028
# 500-999       921
# Name: company_size, dtype: int64

# %%
df.relevant_experience.value_counts()
# Out:
# Has relevant experience    8259
# No relevant experience     3235
# Name: relevant_experience, dtype: int64

# %%
df.company_type.value_counts()
# Out:
# Pvt Ltd                7584
# Public sector          1208
# Early stage startup     954
# Funded startup          896
# NGO                     564
# Other                   288
# Name: company_type, dtype: int64

# %%
df['relevant_experience'] = np.where(df['relevant_experience'] == "Has relevant experience", 1, 0)

# %%
df
# Out:
#          cid  city.100  city.10  city.105  city.103  city.104  city.102  \
# 0       7124         0        0         0         0         0         0
# 1         51         0        0         1         0         0         0
# 2      13137         0        0         0         0         0         0
# 3       2769         0        0         0         0         0         0
# 4       8374         0        0         0         0         0         0
# ...      ...       ...      ...       ...       ...       ...       ...
# 11489  14834         0        0         0         0         1         0
# 11490  14996         0        0         0         0         1         0
# 11491   5960         0        0         0         0         1         0
# 11492   5867         0        0         0         0         0         0
# 11493   8376         0        0         0         0         1         0
#
#        city.101  city.2119  city.114  ...  education_level  \
# ...

# %%
df1.info()

# %%
df1.describe()
# Out:
#                 cid      city.100       city.10      city.105      city.103  \
# count  11494.000000  11494.000000  11494.000000  11494.000000  11494.000000
# mean    9564.860536      0.004872      0.013920      0.004002      0.016530
# std     5535.738475      0.069633      0.117165      0.063138      0.127509
# min        2.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4785.250000      0.000000      0.000000      0.000000      0.000000
# 50%     9553.500000      0.000000      0.000000      0.000000      0.000000
# 75%    14372.750000      0.000000      0.000000      0.000000      0.000000
# max    19158.000000      1.000000      1.000000      1.000000      1.000000
#
#            city.104      city.102      city.101     city.2119      city.114  \
# count  11494.000000  11494.000000  11494.000000  11494.000000  11494.000000
# mean       0.226118      0.015312      0.004002      0.012528      0.073691
# ...

# %%
df1.describe(include=['O'])
# Out:
#        gender enrolled_university education_level academic_discipline  \
# count   11494               11494           11494               11494
# unique      3                   3               5                   6
# top      Male       No enrollment   Undergraduate                STEM
# freq     9706                8321            7066               10085
#
#        experience company_size company_type last_new_job  \
# count       11494        11494        11494        11494
# unique         22            8            6            6
# top           >20        50-99      Pvt Ltd            1
# freq         1987         2282         7584         4907
#
#             relevant_experience target
# count                     11494  11494
# unique                        2      2
# top     Has relevant experience     no
# freq                       8259   8676

# %%
df1.isnull().sum()
# Out:
# cid                       0
# city.100                  0
# city.10                   0
# city.105                  0
# city.103                  0
#                          ..
# last_new_job              0
# city_development_index    0
# relevant_experience       0
# training_hours            0
# target                    0
# Length: 73, dtype: int64
